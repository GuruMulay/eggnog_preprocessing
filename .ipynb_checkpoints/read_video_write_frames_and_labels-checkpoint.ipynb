# %%
import numpy as np
import pandas as pd
np.set_printoptions(threshold=np.inf, precision=4)
import os
import cv2

# %%
def load_skeleton_data_for_video(file_video_path):
    print(file_video_path[:-9])
    xyz_skeleton_data = np.loadtxt(file_video_path[:-9] + 'Skeleton.txt', dtype='float', delimiter=',', skiprows=1, 
                                   usecols=(1,  # Time
                                            9,10,11,  # SpineBase 0
                                            18,19,20,  # SpineMid 
                                            27,28,29,  # Neck
                                            36,37,38,  # Head
                                            45,46,47,  # ShoulderLeft
                                            54,55,56,  # ElbowLeft
                                            63,64,65,  # WristLeft
                                            72,73,74,  # HandLeft
                                            81,82,83,  # ShoulderRight
                                            90,91,92,  # ElbowRight
                                            99,100,101,  # WristRight
                                            108,109,110,  # HandRight
                                            117,118,119,  # HipLeft (added)
                                            # 126,127,128,  # KneeLeft
                                            # 135,136,137,  # AnkleLeft
                                            # 144,145,146,  # FootLeft
                                            153,154,155,  # HipRight (added)
                                            # 162,163,164,  # KneeRight
                                            # 171,172,173,  # AnkleRight
                                            # 180,181,182,  # FootRight
                                            189,190,191,  # SpineShoulder
                                            198,199,200,  # HandTipLeft
                                            207,208,209,  # ThumbLeft
                                            216,217,218,  # HandTipRight
                                            225,226,227  # ThumbRight 
                                           ))
    
    assert(xyz_skeleton_data.shape[1] == 58) # 19 joints * 3 (x,y,z) + 1 (time)
    print("xyz_skeleton_data.shape", xyz_skeleton_data.shape)
    
#     cnv = {1: lambda s: np.float(s.strip() or 'Nan')}

#     rgb_skeleton_data = np.loadtxt(file_video_path[:-9] + 'RGBSkeleton.txt', dtype='float', delimiter=',', skiprows=1, 
#                                    converters=cnv, 
#                                    usecols=(8,9,
#                                              16,17,
#                                              24,25,
#                                              32,33,
#                                              40,41,
#                                              48,49,
#                                              56,57,
#                                              64,65,
#                                              72,73,
#                                              80,81,
#                                              88,89,
#                                              96,97,
#                                              104,105,  # HipLeft
#                                              # 112,113,  # KneeLeft
#                                              # 120,121,  # AnkleLeft
#                                              # 128,129,  # FootLeft
#                                              136,137,
#                                              # 144,145,  # KneeRight
#                                              # 152,153,  # AnkleRight
#                                              # 160,161,  # FootRight
#                                              168,169,  # SpineShoulder
#                                              176,177,  # HandTipLeft
#                                              184,185,  # ThumbLeft
#                                              192,193,  # HandTipRight
#                                              200,201  # ThumbRight
#                                             ))

    visible_skeleton_kp = [8,9,
                           16,17,
                           24,25,
                           32,33,
                           40,41,
                           48,49,
                           56,57,
                           64,65,
                           72,73,
                           80,81,
                           88,89,
                           96,97,
                           104,105,  # HipLeft
                           # 112,113,  # KneeLeft
                           # 120,121,  # AnkleLeft
                           # 128,129,  # FootLeft
                           136,137,
                           # 144,145,  # KneeRight
                           # 152,153,  # AnkleRight
                           # 160,161,  # FootRight
                           168,169,  # SpineShoulder
                           176,177,  # HandTipLeft
                           184,185,  # ThumbLeft
                           192,193,  # HandTipRight
                           200,201  # ThumbRight
                          ]
    
    symbol_inf_neg = "-∞"
    symbol_inf_pos = "∞"
    rgb_skeleton_data = []
    
    with open(file_video_path[:-9] + 'RGBSkeleton.txt') as rgb_sk:
        next(rgb_sk)
        line_index = 0
        for line in rgb_sk:
            cols = line.split(',')
            cols_actual_data = [cols[i] for i in visible_skeleton_kp]
            # print(len(cols), len(cols_actual_data), cols_actual_data)
            
            for j, field in enumerate(cols_actual_data):
                if symbol_inf_neg in field or symbol_inf_pos in field:
                    cols_actual_data[j] = np.inf
                else:
                    cols_actual_data[j] = np.float64(field)
            # append 'time' from column 0 of the xyz_skeleton_data to the column 0 of cols_actual_data
            cols_actual_data.insert(0, xyz_skeleton_data[line_index][0])
            # print(len(cols), len(cols_actual_data), cols_actual_data)
            line_index += 1
            assert(len(cols_actual_data) == 39) # 19 joints * 2 (x,y) + 1 (Time)
            rgb_skeleton_data.append(cols_actual_data)
            
            
    rgb_skeleton_data = np.array(rgb_skeleton_data)
    # print("rgb_skeleton_data.shape", rgb_skeleton_data)
    
    assert(xyz_skeleton_data.shape[0] == rgb_skeleton_data.shape[0])
    assert((xyz_skeleton_data[...,0] == rgb_skeleton_data[...,0]).all())
    
    
    return xyz_skeleton_data, rgb_skeleton_data


def load_frames_file(file_video_path):
#     dt = pd.read_csv(file_video_path[:-4] + '.frames', index_col=0, skiprows=1, usecols=(0,1)).T.to_dict()
    frame_time_dict = dict()
    with open(file_video_path[:-4] + '.frames') as frames:
        next(frames)
        for line in frames:
            cols = line.split(',')
            frame_time_dict[np.int64(cols[0])] = np.float64(cols[1])
            
    print("total frames in the video = ", len(frame_time_dict))
    return frame_time_dict

def find_nearest_frameindex_from_skeleton_file(sk_time_array, time):
    idx = (np.abs(sk_time_array - time)).argmin()
    return idx, sk_time_array[idx]
    
def save_2d_keypoints_and_images(video_name, video_path, npy_path, rgb_skeleton_data, frame_time_dict):
    mismatch_count = 0
    cap = cv2.VideoCapture(video_path)
    assert(cap.isOpened() == True)
    for k in frame_time_dict.keys():
        nearest_idx, nearest_time = find_nearest_frameindex_from_skeleton_file(rgb_skeleton_data[...,0], frame_time_dict[k]) 
        print("k (video frame) ", k, "\t time", frame_time_dict[k], "\t nearest_idx from skeleton file", nearest_idx, "\t nearest_time", nearest_time)        
        # print("k=>", k, nearest_idx, "<= nearest_idx")
       
        if (abs(frame_time_dict[k] - nearest_time) > 1000000):  # 100 ns ticks, so 1000000 = 0.1sec
            mismatch_count += 1
            continue  # do not add the nearest found index if the difference is really big (>0.1sec)
        else:         
            # print(rgb_skeleton_data[nearest_idx])
            if(np.inf not in rgb_skeleton_data[nearest_idx]):  # do not add if there is np.inf in the line
                # save image with the original resolution
                cap.set(cv2.CAP_PROP_POS_FRAMES, k)
                success, frame  = cap.read()
                if success:
                    os.makedirs(os.path.join(npy_path, video_name), exist_ok=True)
                    save_dir = os.path.join(npy_path, video_name)
                    
                    print("kth frame =", k, frame.shape, "\n")
                    cv2.imwrite(os.path.join(save_dir, video_name + "_vfr_" + str(k) + "_skfr_" + str(nearest_idx) + '.jpg'), frame)
                    
                    # print(rgb_skeleton_data[nearest_idx])
                    print(save_dir, os.path.join("", video_name + "_vfr_" + str(k) + "_skfr_" + str(nearest_idx) + '.npy'))
                    np.save(os.path.join(save_dir, video_name + "_vfr_" + str(k) + "_skfr_" + str(nearest_idx) + '.npy'), rgb_skeleton_data[nearest_idx][1:])  # index 0 is time
    cap.release()
    print("mismatch_count =",  mismatch_count)

# %%
file_path = '/s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video.avi'
video_name = file_path.split("/")[-1]
print(video_name)
xyz_skeleton_data, rgb_skeleton_data = load_skeleton_data_for_video(file_path)
# print(xyz_skeleton_data, "\n\n", rgb_skeleton_data)
# print(xyz_skeleton_data[...,0])
# print(rgb_skeleton_data[...,0])

frame_time_dict = load_frames_file(file_path)

npy_path = '/s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/'

video_path = file_path
save_2d_keypoints_and_images(video_name[:-4], video_path, npy_path, rgb_skeleton_data, frame_time_dict)
# Out:
# 20160205_191417_00_Video.avi
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_
# xyz_skeleton_data.shape (611, 58)
# total frames in the video =  617
# k (video frame)  0 	 time 0.0 	 nearest_idx from skeleton file 0 	 nearest_time 164674.0
# k (video frame)  1 	 time 333333.0 	 nearest_idx from skeleton file 0 	 nearest_time 164674.0
# k (video frame)  2 	 time 666666.0 	 nearest_idx from skeleton file 1 	 nearest_time 504780.0
# k (video frame)  3 	 time 1000000.0 	 nearest_idx from skeleton file 2 	 nearest_time 1164687.0
# k (video frame)  4 	 time 1666666.0 	 nearest_idx from skeleton file 3 	 nearest_time 1505084.0
# k (video frame)  5 	 time 2000000.0 	 nearest_idx from skeleton file 5 	 nearest_time 2164700.0
# k (video frame)  6 	 time 2333333.0 	 nearest_idx from skeleton file 5 	 nearest_time 2164700.0
# k (video frame)  7 	 time 2666666.0 	 nearest_idx from skeleton file 6 	 nearest_time 2504789.0
# k (video frame)  8 	 time 3000000.0 	 nearest_idx from skeleton file 7 	 nearest_time 2834025.0
# k (video frame)  9 	 time 3333333.0 	 nearest_idx from skeleton file 8 	 nearest_time 3504822.0
# kth frame = 9 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_9_skfr_8.npy
# k (video frame)  10 	 time 4000000.0 	 nearest_idx from skeleton file 10 	 nearest_time 4164690.0
# kth frame = 10 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_10_skfr_10.npy
# k (video frame)  11 	 time 4333333.0 	 nearest_idx from skeleton file 10 	 nearest_time 4164690.0
# kth frame = 11 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_11_skfr_10.npy
# k (video frame)  12 	 time 4666666.0 	 nearest_idx from skeleton file 11 	 nearest_time 4504812.0
# kth frame = 12 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_12_skfr_11.npy
# k (video frame)  13 	 time 5000000.0 	 nearest_idx from skeleton file 12 	 nearest_time 4833983.0
# kth frame = 13 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_13_skfr_12.npy
# k (video frame)  14 	 time 5333333.0 	 nearest_idx from skeleton file 13 	 nearest_time 5504795.0
# kth frame = 14 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_14_skfr_13.npy
# k (video frame)  15 	 time 6000000.0 	 nearest_idx from skeleton file 15 	 nearest_time 6164675.0
# kth frame = 15 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_15_skfr_15.npy
# k (video frame)  16 	 time 6333333.0 	 nearest_idx from skeleton file 15 	 nearest_time 6164675.0
# kth frame = 16 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_16_skfr_15.npy
# k (video frame)  17 	 time 6666666.0 	 nearest_idx from skeleton file 16 	 nearest_time 6504752.0
# kth frame = 17 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_17_skfr_16.npy
# k (video frame)  18 	 time 7333333.0 	 nearest_idx from skeleton file 18 	 nearest_time 7164685.0
# kth frame = 18 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_18_skfr_18.npy
# k (video frame)  19 	 time 7666666.0 	 nearest_idx from skeleton file 19 	 nearest_time 7834151.0
# kth frame = 19 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_19_skfr_19.npy
# k (video frame)  20 	 time 8000000.0 	 nearest_idx from skeleton file 20 	 nearest_time 8164839.0
# kth frame = 20 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_20_skfr_20.npy
# k (video frame)  21 	 time 8333333.0 	 nearest_idx from skeleton file 20 	 nearest_time 8164839.0
# kth frame = 21 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_21_skfr_20.npy
# k (video frame)  22 	 time 8666666.0 	 nearest_idx from skeleton file 21 	 nearest_time 8505024.0
# kth frame = 22 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_22_skfr_21.npy
# k (video frame)  23 	 time 9000000.0 	 nearest_idx from skeleton file 23 	 nearest_time 9164687.0
# kth frame = 23 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_23_skfr_23.npy
# k (video frame)  24 	 time 9333333.0 	 nearest_idx from skeleton file 23 	 nearest_time 9164687.0
# kth frame = 24 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_24_skfr_23.npy
# k (video frame)  25 	 time 9666666.0 	 nearest_idx from skeleton file 24 	 nearest_time 9504955.0
# kth frame = 25 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_25_skfr_24.npy
# k (video frame)  26 	 time 10000000.0 	 nearest_idx from skeleton file 25 	 nearest_time 9833998.0
# kth frame = 26 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_26_skfr_25.npy
# k (video frame)  27 	 time 10333333.0 	 nearest_idx from skeleton file 26 	 nearest_time 10504980.0
# kth frame = 27 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_27_skfr_26.npy
# k (video frame)  28 	 time 11000000.0 	 nearest_idx from skeleton file 28 	 nearest_time 11164681.0
# kth frame = 28 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_28_skfr_28.npy
# k (video frame)  29 	 time 11333333.0 	 nearest_idx from skeleton file 28 	 nearest_time 11164681.0
# kth frame = 29 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_29_skfr_28.npy
# k (video frame)  30 	 time 11666666.0 	 nearest_idx from skeleton file 29 	 nearest_time 11504749.0
# kth frame = 30 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_30_skfr_29.npy
# k (video frame)  31 	 time 12000000.0 	 nearest_idx from skeleton file 31 	 nearest_time 12164831.0
# kth frame = 31 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_31_skfr_31.npy
# k (video frame)  32 	 time 12333333.0 	 nearest_idx from skeleton file 31 	 nearest_time 12164831.0
# kth frame = 32 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_32_skfr_31.npy
# k (video frame)  33 	 time 12666666.0 	 nearest_idx from skeleton file 32 	 nearest_time 12504742.0
# kth frame = 33 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_33_skfr_32.npy
# k (video frame)  34 	 time 13000000.0 	 nearest_idx from skeleton file 34 	 nearest_time 13164862.0
# kth frame = 34 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_34_skfr_34.npy
# k (video frame)  35 	 time 13333333.0 	 nearest_idx from skeleton file 34 	 nearest_time 13164862.0
# kth frame = 35 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_35_skfr_34.npy
# k (video frame)  36 	 time 13666666.0 	 nearest_idx from skeleton file 35 	 nearest_time 13833976.0
# kth frame = 36 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_36_skfr_35.npy
# k (video frame)  37 	 time 14000000.0 	 nearest_idx from skeleton file 36 	 nearest_time 14164734.0
# kth frame = 37 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_37_skfr_36.npy
# k (video frame)  38 	 time 14333333.0 	 nearest_idx from skeleton file 36 	 nearest_time 14164734.0
# kth frame = 38 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_38_skfr_36.npy
# k (video frame)  39 	 time 14666666.0 	 nearest_idx from skeleton file 37 	 nearest_time 14504976.0
# kth frame = 39 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_39_skfr_37.npy
# k (video frame)  40 	 time 15333333.0 	 nearest_idx from skeleton file 39 	 nearest_time 15164817.0
# kth frame = 40 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_40_skfr_39.npy
# k (video frame)  41 	 time 15666666.0 	 nearest_idx from skeleton file 40 	 nearest_time 15504822.0
# kth frame = 41 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_41_skfr_40.npy
# k (video frame)  42 	 time 16000000.0 	 nearest_idx from skeleton file 42 	 nearest_time 16164833.0
# kth frame = 42 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_42_skfr_42.npy
# k (video frame)  43 	 time 16333333.0 	 nearest_idx from skeleton file 42 	 nearest_time 16164833.0
# kth frame = 43 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_43_skfr_42.npy
# k (video frame)  44 	 time 16666666.0 	 nearest_idx from skeleton file 43 	 nearest_time 16834100.0
# kth frame = 44 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_44_skfr_43.npy
# k (video frame)  45 	 time 17000000.0 	 nearest_idx from skeleton file 44 	 nearest_time 17164702.0
# kth frame = 45 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_45_skfr_44.npy
# k (video frame)  46 	 time 17666666.0 	 nearest_idx from skeleton file 45 	 nearest_time 17504742.0
# kth frame = 46 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_46_skfr_45.npy
# k (video frame)  47 	 time 18000000.0 	 nearest_idx from skeleton file 47 	 nearest_time 18164674.0
# kth frame = 47 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_47_skfr_47.npy
# k (video frame)  48 	 time 18333333.0 	 nearest_idx from skeleton file 47 	 nearest_time 18164674.0
# kth frame = 48 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_48_skfr_47.npy
# k (video frame)  49 	 time 19000000.0 	 nearest_idx from skeleton file 49 	 nearest_time 19164869.0
# kth frame = 49 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_49_skfr_49.npy
# k (video frame)  50 	 time 19333333.0 	 nearest_idx from skeleton file 49 	 nearest_time 19164869.0
# kth frame = 50 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_50_skfr_49.npy
# k (video frame)  51 	 time 19666666.0 	 nearest_idx from skeleton file 50 	 nearest_time 19504741.0
# kth frame = 51 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_51_skfr_50.npy
# k (video frame)  52 	 time 20000000.0 	 nearest_idx from skeleton file 52 	 nearest_time 20164668.0
# kth frame = 52 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_52_skfr_52.npy
# k (video frame)  53 	 time 20333333.0 	 nearest_idx from skeleton file 52 	 nearest_time 20164668.0
# kth frame = 53 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_53_skfr_52.npy
# k (video frame)  54 	 time 20666666.0 	 nearest_idx from skeleton file 53 	 nearest_time 20504783.0
# kth frame = 54 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_54_skfr_53.npy
# k (video frame)  55 	 time 21000000.0 	 nearest_idx from skeleton file 55 	 nearest_time 21164678.0
# kth frame = 55 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_55_skfr_55.npy
# k (video frame)  56 	 time 21333333.0 	 nearest_idx from skeleton file 55 	 nearest_time 21164678.0
# kth frame = 56 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_56_skfr_55.npy
# k (video frame)  57 	 time 21666666.0 	 nearest_idx from skeleton file 56 	 nearest_time 21504793.0
# kth frame = 57 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_57_skfr_56.npy
# k (video frame)  58 	 time 22000000.0 	 nearest_idx from skeleton file 58 	 nearest_time 22164805.0
# kth frame = 58 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_58_skfr_58.npy
# k (video frame)  59 	 time 22333333.0 	 nearest_idx from skeleton file 58 	 nearest_time 22164805.0
# kth frame = 59 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_59_skfr_58.npy
# k (video frame)  60 	 time 22666666.0 	 nearest_idx from skeleton file 59 	 nearest_time 22504959.0
# kth frame = 60 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_60_skfr_59.npy
# k (video frame)  61 	 time 23000000.0 	 nearest_idx from skeleton file 61 	 nearest_time 23164736.0
# kth frame = 61 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_61_skfr_61.npy
# k (video frame)  62 	 time 23666666.0 	 nearest_idx from skeleton file 62 	 nearest_time 23834114.0
# kth frame = 62 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_62_skfr_62.npy
# k (video frame)  63 	 time 24000000.0 	 nearest_idx from skeleton file 63 	 nearest_time 24164728.0
# kth frame = 63 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_63_skfr_63.npy
# k (video frame)  64 	 time 24333333.0 	 nearest_idx from skeleton file 63 	 nearest_time 24164728.0
# kth frame = 64 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_64_skfr_63.npy
# k (video frame)  65 	 time 25000000.0 	 nearest_idx from skeleton file 65 	 nearest_time 25164732.0
# kth frame = 65 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_65_skfr_65.npy
# k (video frame)  66 	 time 25333333.0 	 nearest_idx from skeleton file 65 	 nearest_time 25164732.0
# kth frame = 66 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_66_skfr_65.npy
# k (video frame)  67 	 time 25666666.0 	 nearest_idx from skeleton file 66 	 nearest_time 25504786.0
# kth frame = 67 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_67_skfr_66.npy
# k (video frame)  68 	 time 26000000.0 	 nearest_idx from skeleton file 68 	 nearest_time 26164666.0
# kth frame = 68 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_68_skfr_68.npy
# k (video frame)  69 	 time 26333333.0 	 nearest_idx from skeleton file 68 	 nearest_time 26164666.0
# kth frame = 69 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_69_skfr_68.npy
# k (video frame)  70 	 time 26666666.0 	 nearest_idx from skeleton file 69 	 nearest_time 26833947.0
# kth frame = 70 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_70_skfr_69.npy
# k (video frame)  71 	 time 27333333.0 	 nearest_idx from skeleton file 70 	 nearest_time 27164682.0
# kth frame = 71 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_71_skfr_70.npy
# k (video frame)  72 	 time 27666666.0 	 nearest_idx from skeleton file 71 	 nearest_time 27504944.0
# kth frame = 72 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_72_skfr_71.npy
# k (video frame)  73 	 time 28000000.0 	 nearest_idx from skeleton file 73 	 nearest_time 28164686.0
# kth frame = 73 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_73_skfr_73.npy
# k (video frame)  74 	 time 28333333.0 	 nearest_idx from skeleton file 73 	 nearest_time 28164686.0
# kth frame = 74 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_74_skfr_73.npy
# k (video frame)  75 	 time 28666666.0 	 nearest_idx from skeleton file 74 	 nearest_time 28504828.0
# kth frame = 75 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_75_skfr_74.npy
# k (video frame)  76 	 time 29000000.0 	 nearest_idx from skeleton file 75 	 nearest_time 29165060.0
# kth frame = 76 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_76_skfr_75.npy
# k (video frame)  77 	 time 29666666.0 	 nearest_idx from skeleton file 76 	 nearest_time 29504979.0
# kth frame = 77 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_77_skfr_76.npy
# k (video frame)  78 	 time 30000000.0 	 nearest_idx from skeleton file 78 	 nearest_time 30164917.0
# kth frame = 78 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_78_skfr_78.npy
# k (video frame)  79 	 time 30333333.0 	 nearest_idx from skeleton file 78 	 nearest_time 30164917.0
# kth frame = 79 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_79_skfr_78.npy
# k (video frame)  80 	 time 30666666.0 	 nearest_idx from skeleton file 79 	 nearest_time 30504801.0
# kth frame = 80 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_80_skfr_79.npy
# k (video frame)  81 	 time 31000000.0 	 nearest_idx from skeleton file 80 	 nearest_time 30833955.0
# kth frame = 81 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_81_skfr_80.npy
# k (video frame)  82 	 time 31333333.0 	 nearest_idx from skeleton file 81 	 nearest_time 31504905.0
# kth frame = 82 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_82_skfr_81.npy
# k (video frame)  83 	 time 31666666.0 	 nearest_idx from skeleton file 81 	 nearest_time 31504905.0
# kth frame = 83 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_83_skfr_81.npy
# k (video frame)  84 	 time 32000000.0 	 nearest_idx from skeleton file 83 	 nearest_time 32164943.0
# kth frame = 84 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_84_skfr_83.npy
# k (video frame)  85 	 time 32333333.0 	 nearest_idx from skeleton file 83 	 nearest_time 32164943.0
# kth frame = 85 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_85_skfr_83.npy
# k (video frame)  86 	 time 32666666.0 	 nearest_idx from skeleton file 84 	 nearest_time 32504789.0
# kth frame = 86 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_86_skfr_84.npy
# k (video frame)  87 	 time 33000000.0 	 nearest_idx from skeleton file 86 	 nearest_time 33164833.0
# kth frame = 87 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_87_skfr_86.npy
# k (video frame)  88 	 time 33333333.0 	 nearest_idx from skeleton file 86 	 nearest_time 33164833.0
# kth frame = 88 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_88_skfr_86.npy
# k (video frame)  89 	 time 33666666.0 	 nearest_idx from skeleton file 87 	 nearest_time 33504942.0
# kth frame = 89 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_89_skfr_87.npy
# k (video frame)  90 	 time 34000000.0 	 nearest_idx from skeleton file 89 	 nearest_time 34164687.0
# kth frame = 90 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_90_skfr_89.npy
# k (video frame)  91 	 time 34333333.0 	 nearest_idx from skeleton file 89 	 nearest_time 34164687.0
# kth frame = 91 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_91_skfr_89.npy
# k (video frame)  92 	 time 35000000.0 	 nearest_idx from skeleton file 91 	 nearest_time 35164659.0
# kth frame = 92 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_92_skfr_91.npy
# k (video frame)  93 	 time 35333333.0 	 nearest_idx from skeleton file 91 	 nearest_time 35164659.0
# kth frame = 93 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_93_skfr_91.npy
# k (video frame)  94 	 time 35666666.0 	 nearest_idx from skeleton file 92 	 nearest_time 35504883.0
# kth frame = 94 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_94_skfr_92.npy
# k (video frame)  95 	 time 36000000.0 	 nearest_idx from skeleton file 94 	 nearest_time 36164651.0
# kth frame = 95 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_95_skfr_94.npy
# k (video frame)  96 	 time 36333333.0 	 nearest_idx from skeleton file 94 	 nearest_time 36164651.0
# kth frame = 96 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_96_skfr_94.npy
# k (video frame)  97 	 time 36666666.0 	 nearest_idx from skeleton file 95 	 nearest_time 36833991.0
# kth frame = 97 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_97_skfr_95.npy
# k (video frame)  98 	 time 37000000.0 	 nearest_idx from skeleton file 96 	 nearest_time 37164638.0
# kth frame = 98 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_98_skfr_96.npy
# k (video frame)  99 	 time 37666666.0 	 nearest_idx from skeleton file 97 	 nearest_time 37504751.0
# kth frame = 99 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_99_skfr_97.npy
# k (video frame)  100 	 time 38000000.0 	 nearest_idx from skeleton file 99 	 nearest_time 38164668.0
# kth frame = 100 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_100_skfr_99.npy
# k (video frame)  101 	 time 38333333.0 	 nearest_idx from skeleton file 99 	 nearest_time 38164668.0
# kth frame = 101 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_101_skfr_99.npy
# k (video frame)  102 	 time 38666666.0 	 nearest_idx from skeleton file 100 	 nearest_time 38504772.0
# kth frame = 102 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_102_skfr_100.npy
# k (video frame)  103 	 time 39000000.0 	 nearest_idx from skeleton file 101 	 nearest_time 39164758.0
# kth frame = 103 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_103_skfr_101.npy
# k (video frame)  104 	 time 39333333.0 	 nearest_idx from skeleton file 101 	 nearest_time 39164758.0
# kth frame = 104 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_104_skfr_101.npy
# k (video frame)  105 	 time 39666666.0 	 nearest_idx from skeleton file 102 	 nearest_time 39504905.0
# kth frame = 105 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_105_skfr_102.npy
# k (video frame)  106 	 time 40333333.0 	 nearest_idx from skeleton file 104 	 nearest_time 40164688.0
# kth frame = 106 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_106_skfr_104.npy
# k (video frame)  107 	 time 40666666.0 	 nearest_idx from skeleton file 105 	 nearest_time 40504936.0
# kth frame = 107 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_107_skfr_105.npy
# k (video frame)  108 	 time 41000000.0 	 nearest_idx from skeleton file 107 	 nearest_time 41164692.0
# kth frame = 108 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_108_skfr_107.npy
# k (video frame)  109 	 time 41333333.0 	 nearest_idx from skeleton file 107 	 nearest_time 41164692.0
# kth frame = 109 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_109_skfr_107.npy
# k (video frame)  110 	 time 41666666.0 	 nearest_idx from skeleton file 108 	 nearest_time 41505007.0
# kth frame = 110 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_110_skfr_108.npy
# k (video frame)  111 	 time 42000000.0 	 nearest_idx from skeleton file 109 	 nearest_time 42164700.0
# kth frame = 111 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_111_skfr_109.npy
# k (video frame)  112 	 time 42333333.0 	 nearest_idx from skeleton file 109 	 nearest_time 42164700.0
# kth frame = 112 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_112_skfr_109.npy
# k (video frame)  113 	 time 43000000.0 	 nearest_idx from skeleton file 112 	 nearest_time 43164941.0
# kth frame = 113 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_113_skfr_112.npy
# k (video frame)  114 	 time 43333333.0 	 nearest_idx from skeleton file 112 	 nearest_time 43164941.0
# kth frame = 114 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_114_skfr_112.npy
# k (video frame)  115 	 time 43666666.0 	 nearest_idx from skeleton file 113 	 nearest_time 43504796.0
# kth frame = 115 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_115_skfr_113.npy
# k (video frame)  116 	 time 44000000.0 	 nearest_idx from skeleton file 114 	 nearest_time 43833973.0
# kth frame = 116 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_116_skfr_114.npy
# k (video frame)  117 	 time 44666666.0 	 nearest_idx from skeleton file 115 	 nearest_time 44504747.0
# kth frame = 117 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_117_skfr_115.npy
# k (video frame)  118 	 time 45000000.0 	 nearest_idx from skeleton file 117 	 nearest_time 45164794.0
# kth frame = 118 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_118_skfr_117.npy
# k (video frame)  119 	 time 45333333.0 	 nearest_idx from skeleton file 117 	 nearest_time 45164794.0
# kth frame = 119 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_119_skfr_117.npy
# k (video frame)  120 	 time 45666666.0 	 nearest_idx from skeleton file 118 	 nearest_time 45504739.0
# kth frame = 120 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_120_skfr_118.npy
# k (video frame)  121 	 time 46000000.0 	 nearest_idx from skeleton file 120 	 nearest_time 46164810.0
# kth frame = 121 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_121_skfr_120.npy
# k (video frame)  122 	 time 46333333.0 	 nearest_idx from skeleton file 120 	 nearest_time 46164810.0
# kth frame = 122 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_122_skfr_120.npy
# k (video frame)  123 	 time 46666666.0 	 nearest_idx from skeleton file 121 	 nearest_time 46834024.0
# kth frame = 123 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_123_skfr_121.npy
# k (video frame)  124 	 time 47000000.0 	 nearest_idx from skeleton file 122 	 nearest_time 47164861.0
# kth frame = 124 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_124_skfr_122.npy
# k (video frame)  125 	 time 47333333.0 	 nearest_idx from skeleton file 122 	 nearest_time 47164861.0
# kth frame = 125 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_125_skfr_122.npy
# k (video frame)  126 	 time 48000000.0 	 nearest_idx from skeleton file 125 	 nearest_time 48164613.0
# kth frame = 126 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_126_skfr_125.npy
# k (video frame)  127 	 time 48333333.0 	 nearest_idx from skeleton file 125 	 nearest_time 48164613.0
# kth frame = 127 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_127_skfr_125.npy
# k (video frame)  128 	 time 48666666.0 	 nearest_idx from skeleton file 126 	 nearest_time 48504769.0
# kth frame = 128 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_128_skfr_126.npy
# k (video frame)  129 	 time 49000000.0 	 nearest_idx from skeleton file 128 	 nearest_time 49164643.0
# kth frame = 129 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_129_skfr_128.npy
# k (video frame)  130 	 time 49333333.0 	 nearest_idx from skeleton file 128 	 nearest_time 49164643.0
# kth frame = 130 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_130_skfr_128.npy
# k (video frame)  131 	 time 49666666.0 	 nearest_idx from skeleton file 129 	 nearest_time 49833977.0
# kth frame = 131 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_131_skfr_129.npy
# k (video frame)  132 	 time 50000000.0 	 nearest_idx from skeleton file 130 	 nearest_time 50164838.0
# kth frame = 132 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_132_skfr_130.npy
# k (video frame)  133 	 time 50666666.0 	 nearest_idx from skeleton file 131 	 nearest_time 50504939.0
# kth frame = 133 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_133_skfr_131.npy
# k (video frame)  134 	 time 51000000.0 	 nearest_idx from skeleton file 133 	 nearest_time 51164616.0
# kth frame = 134 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_134_skfr_133.npy
# k (video frame)  135 	 time 51333333.0 	 nearest_idx from skeleton file 133 	 nearest_time 51164616.0
# kth frame = 135 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_135_skfr_133.npy
# k (video frame)  136 	 time 51666666.0 	 nearest_idx from skeleton file 134 	 nearest_time 51834003.0
# kth frame = 136 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_136_skfr_134.npy
# k (video frame)  137 	 time 52333333.0 	 nearest_idx from skeleton file 135 	 nearest_time 52164837.0
# kth frame = 137 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_137_skfr_135.npy
# k (video frame)  138 	 time 52666666.0 	 nearest_idx from skeleton file 136 	 nearest_time 52505020.0
# kth frame = 138 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_138_skfr_136.npy
# k (video frame)  139 	 time 53000000.0 	 nearest_idx from skeleton file 137 	 nearest_time 52834113.0
# kth frame = 139 (1080, 1920, 3)
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_139_skfr_137.npy
# k (video frame)  140 	 time 53333333.0 	 nearest_idx from skeleton file 138 	 nearest_time 53504813.0
# kth frame = 140 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_140_skfr_138.npy
# k (video frame)  141 	 time 54000000.0 	 nearest_idx from skeleton file 140 	 nearest_time 54164790.0
# kth frame = 141 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_141_skfr_140.npy
# k (video frame)  142 	 time 54333333.0 	 nearest_idx from skeleton file 140 	 nearest_time 54164790.0
# kth frame = 142 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_142_skfr_140.npy
# k (video frame)  143 	 time 54666666.0 	 nearest_idx from skeleton file 141 	 nearest_time 54504768.0
# kth frame = 143 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_143_skfr_141.npy
# k (video frame)  144 	 time 55000000.0 	 nearest_idx from skeleton file 142 	 nearest_time 54834039.0
# kth frame = 144 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_144_skfr_142.npy
# k (video frame)  145 	 time 55333333.0 	 nearest_idx from skeleton file 143 	 nearest_time 55504877.0
# kth frame = 145 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_145_skfr_143.npy
# k (video frame)  146 	 time 56000000.0 	 nearest_idx from skeleton file 145 	 nearest_time 56164672.0
# kth frame = 146 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_146_skfr_145.npy
# k (video frame)  147 	 time 56333333.0 	 nearest_idx from skeleton file 145 	 nearest_time 56164672.0
# kth frame = 147 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_147_skfr_145.npy
# k (video frame)  148 	 time 56666666.0 	 nearest_idx from skeleton file 146 	 nearest_time 56504788.0
# kth frame = 148 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_148_skfr_146.npy
# k (video frame)  149 	 time 57000000.0 	 nearest_idx from skeleton file 148 	 nearest_time 57164650.0
# kth frame = 149 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_149_skfr_148.npy
# k (video frame)  150 	 time 57333333.0 	 nearest_idx from skeleton file 148 	 nearest_time 57164650.0
# kth frame = 150 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_150_skfr_148.npy
# k (video frame)  151 	 time 57666666.0 	 nearest_idx from skeleton file 149 	 nearest_time 57504909.0
# kth frame = 151 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_151_skfr_149.npy
# k (video frame)  152 	 time 58000000.0 	 nearest_idx from skeleton file 151 	 nearest_time 58164821.0
# kth frame = 152 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_152_skfr_151.npy
# k (video frame)  153 	 time 58333333.0 	 nearest_idx from skeleton file 151 	 nearest_time 58164821.0
# kth frame = 153 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_153_skfr_151.npy
# k (video frame)  154 	 time 58666666.0 	 nearest_idx from skeleton file 152 	 nearest_time 58833920.0
# kth frame = 154 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_154_skfr_152.npy
# k (video frame)  155 	 time 59333333.0 	 nearest_idx from skeleton file 153 	 nearest_time 59164825.0
# kth frame = 155 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_155_skfr_153.npy
# k (video frame)  156 	 time 59666666.0 	 nearest_idx from skeleton file 154 	 nearest_time 59504911.0
# kth frame = 156 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_156_skfr_154.npy
# k (video frame)  157 	 time 60000000.0 	 nearest_idx from skeleton file 156 	 nearest_time 60164826.0
# kth frame = 157 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_157_skfr_156.npy
# k (video frame)  158 	 time 60333333.0 	 nearest_idx from skeleton file 156 	 nearest_time 60164826.0
# kth frame = 158 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_158_skfr_156.npy
# k (video frame)  159 	 time 60666666.0 	 nearest_idx from skeleton file 157 	 nearest_time 60504751.0
# kth frame = 159 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_159_skfr_157.npy
# k (video frame)  160 	 time 61000000.0 	 nearest_idx from skeleton file 158 	 nearest_time 61164748.0
# kth frame = 160 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_160_skfr_158.npy
# k (video frame)  161 	 time 61666666.0 	 nearest_idx from skeleton file 159 	 nearest_time 61504940.0
# kth frame = 161 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_161_skfr_159.npy
# k (video frame)  162 	 time 62000000.0 	 nearest_idx from skeleton file 161 	 nearest_time 62164661.0
# kth frame = 162 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_162_skfr_161.npy
# k (video frame)  163 	 time 62333333.0 	 nearest_idx from skeleton file 161 	 nearest_time 62164661.0
# kth frame = 163 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_163_skfr_161.npy
# k (video frame)  164 	 time 62666666.0 	 nearest_idx from skeleton file 162 	 nearest_time 62504924.0
# kth frame = 164 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_164_skfr_162.npy
# k (video frame)  165 	 time 63000000.0 	 nearest_idx from skeleton file 163 	 nearest_time 62833946.0
# kth frame = 165 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_165_skfr_163.npy
# k (video frame)  166 	 time 63333333.0 	 nearest_idx from skeleton file 164 	 nearest_time 63504825.0
# kth frame = 166 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_166_skfr_164.npy
# k (video frame)  167 	 time 64000000.0 	 nearest_idx from skeleton file 166 	 nearest_time 64164678.0
# kth frame = 167 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_167_skfr_166.npy
# k (video frame)  168 	 time 64333333.0 	 nearest_idx from skeleton file 166 	 nearest_time 64164678.0
# kth frame = 168 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_168_skfr_166.npy
# k (video frame)  169 	 time 64666666.0 	 nearest_idx from skeleton file 167 	 nearest_time 64504952.0
# kth frame = 169 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_169_skfr_167.npy
# k (video frame)  170 	 time 65000000.0 	 nearest_idx from skeleton file 168 	 nearest_time 64833960.0
# kth frame = 170 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_170_skfr_168.npy
# k (video frame)  171 	 time 65666666.0 	 nearest_idx from skeleton file 169 	 nearest_time 65504962.0
# kth frame = 171 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_171_skfr_169.npy
# k (video frame)  172 	 time 66000000.0 	 nearest_idx from skeleton file 171 	 nearest_time 66164807.0
# kth frame = 172 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_172_skfr_171.npy
# k (video frame)  173 	 time 66333333.0 	 nearest_idx from skeleton file 171 	 nearest_time 66164807.0
# kth frame = 173 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_173_skfr_171.npy
# k (video frame)  174 	 time 66666666.0 	 nearest_idx from skeleton file 172 	 nearest_time 66504770.0
# kth frame = 174 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_174_skfr_172.npy
# k (video frame)  175 	 time 67000000.0 	 nearest_idx from skeleton file 173 	 nearest_time 66834164.0
# kth frame = 175 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_175_skfr_173.npy
# k (video frame)  176 	 time 67333333.0 	 nearest_idx from skeleton file 174 	 nearest_time 67505211.0
# kth frame = 176 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_176_skfr_174.npy
# k (video frame)  177 	 time 68000000.0 	 nearest_idx from skeleton file 176 	 nearest_time 68164862.0
# kth frame = 177 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_177_skfr_176.npy
# k (video frame)  178 	 time 68333333.0 	 nearest_idx from skeleton file 176 	 nearest_time 68164862.0
# kth frame = 178 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_178_skfr_176.npy
# k (video frame)  179 	 time 68666666.0 	 nearest_idx from skeleton file 177 	 nearest_time 68504761.0
# kth frame = 179 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_179_skfr_177.npy
# k (video frame)  180 	 time 69000000.0 	 nearest_idx from skeleton file 179 	 nearest_time 69164675.0
# kth frame = 180 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_180_skfr_179.npy
# k (video frame)  181 	 time 69333333.0 	 nearest_idx from skeleton file 179 	 nearest_time 69164675.0
# kth frame = 181 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_181_skfr_179.npy
# k (video frame)  182 	 time 69666666.0 	 nearest_idx from skeleton file 180 	 nearest_time 69833989.0
# kth frame = 182 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_182_skfr_180.npy
# k (video frame)  183 	 time 70000000.0 	 nearest_idx from skeleton file 181 	 nearest_time 70164856.0
# kth frame = 183 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_183_skfr_181.npy
# k (video frame)  184 	 time 70333333.0 	 nearest_idx from skeleton file 181 	 nearest_time 70164856.0
# kth frame = 184 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_184_skfr_181.npy
# k (video frame)  185 	 time 70666666.0 	 nearest_idx from skeleton file 182 	 nearest_time 70504927.0
# kth frame = 185 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_185_skfr_182.npy
# k (video frame)  186 	 time 71000000.0 	 nearest_idx from skeleton file 184 	 nearest_time 71164857.0
# kth frame = 186 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_186_skfr_184.npy
# k (video frame)  187 	 time 71333333.0 	 nearest_idx from skeleton file 184 	 nearest_time 71164857.0
# kth frame = 187 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_187_skfr_184.npy
# k (video frame)  188 	 time 71666666.0 	 nearest_idx from skeleton file 185 	 nearest_time 71504767.0
# kth frame = 188 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_188_skfr_185.npy
# k (video frame)  189 	 time 72000000.0 	 nearest_idx from skeleton file 186 	 nearest_time 71834150.0
# kth frame = 189 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_189_skfr_186.npy
# k (video frame)  190 	 time 72333333.0 	 nearest_idx from skeleton file 187 	 nearest_time 72504927.0
# kth frame = 190 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_190_skfr_187.npy
# k (video frame)  191 	 time 73000000.0 	 nearest_idx from skeleton file 189 	 nearest_time 73164668.0
# kth frame = 191 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_191_skfr_189.npy
# k (video frame)  192 	 time 73333333.0 	 nearest_idx from skeleton file 189 	 nearest_time 73164668.0
# kth frame = 192 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_192_skfr_189.npy
# k (video frame)  193 	 time 73666666.0 	 nearest_idx from skeleton file 190 	 nearest_time 73504778.0
# kth frame = 193 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_193_skfr_190.npy
# k (video frame)  194 	 time 74000000.0 	 nearest_idx from skeleton file 192 	 nearest_time 74164828.0
# kth frame = 194 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_194_skfr_192.npy
# k (video frame)  195 	 time 74333333.0 	 nearest_idx from skeleton file 192 	 nearest_time 74164828.0
# kth frame = 195 (1080, 1920, 3)
#
# ...
# k (video frame)  555 	 time 211333333.0 	 nearest_idx from skeleton file 549 	 nearest_time 211164819.0
# kth frame = 555 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_555_skfr_549.npy
# k (video frame)  556 	 time 211666666.0 	 nearest_idx from skeleton file 550 	 nearest_time 211504717.0
# kth frame = 556 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_556_skfr_550.npy
# k (video frame)  557 	 time 212000000.0 	 nearest_idx from skeleton file 552 	 nearest_time 212164629.0
# kth frame = 557 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_557_skfr_552.npy
# k (video frame)  558 	 time 212333333.0 	 nearest_idx from skeleton file 552 	 nearest_time 212164629.0
# kth frame = 558 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_558_skfr_552.npy
# k (video frame)  559 	 time 212666666.0 	 nearest_idx from skeleton file 553 	 nearest_time 212504806.0
# kth frame = 559 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_559_skfr_553.npy
# k (video frame)  560 	 time 213000000.0 	 nearest_idx from skeleton file 554 	 nearest_time 213164786.0
# kth frame = 560 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_560_skfr_554.npy
# k (video frame)  561 	 time 213666666.0 	 nearest_idx from skeleton file 555 	 nearest_time 213504828.0
# kth frame = 561 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_561_skfr_555.npy
# k (video frame)  562 	 time 214000000.0 	 nearest_idx from skeleton file 557 	 nearest_time 214164775.0
# kth frame = 562 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_562_skfr_557.npy
# k (video frame)  563 	 time 214333333.0 	 nearest_idx from skeleton file 557 	 nearest_time 214164775.0
# kth frame = 563 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_563_skfr_557.npy
# k (video frame)  564 	 time 214666666.0 	 nearest_idx from skeleton file 558 	 nearest_time 214504762.0
# kth frame = 564 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_564_skfr_558.npy
# k (video frame)  565 	 time 215000000.0 	 nearest_idx from skeleton file 559 	 nearest_time 215164703.0
# kth frame = 565 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_565_skfr_559.npy
# k (video frame)  566 	 time 215666666.0 	 nearest_idx from skeleton file 560 	 nearest_time 215504883.0
# kth frame = 566 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_566_skfr_560.npy
# k (video frame)  567 	 time 216000000.0 	 nearest_idx from skeleton file 562 	 nearest_time 216164854.0
# kth frame = 567 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_567_skfr_562.npy
# k (video frame)  568 	 time 216333333.0 	 nearest_idx from skeleton file 562 	 nearest_time 216164854.0
# kth frame = 568 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_568_skfr_562.npy
# k (video frame)  569 	 time 216666666.0 	 nearest_idx from skeleton file 563 	 nearest_time 216504723.0
# kth frame = 569 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_569_skfr_563.npy
# k (video frame)  570 	 time 217000000.0 	 nearest_idx from skeleton file 565 	 nearest_time 217164814.0
# kth frame = 570 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_570_skfr_565.npy
# k (video frame)  571 	 time 217333333.0 	 nearest_idx from skeleton file 565 	 nearest_time 217164814.0
# kth frame = 571 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_571_skfr_565.npy
# k (video frame)  572 	 time 217666666.0 	 nearest_idx from skeleton file 566 	 nearest_time 217504950.0
# kth frame = 572 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_572_skfr_566.npy
# k (video frame)  573 	 time 218000000.0 	 nearest_idx from skeleton file 567 	 nearest_time 218164639.0
# kth frame = 573 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_573_skfr_567.npy
# k (video frame)  574 	 time 218333333.0 	 nearest_idx from skeleton file 567 	 nearest_time 218164639.0
# kth frame = 574 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_574_skfr_567.npy
# k (video frame)  575 	 time 219000000.0 	 nearest_idx from skeleton file 570 	 nearest_time 219164637.0
# kth frame = 575 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_575_skfr_570.npy
# k (video frame)  576 	 time 219333333.0 	 nearest_idx from skeleton file 570 	 nearest_time 219164637.0
# kth frame = 576 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_576_skfr_570.npy
# k (video frame)  577 	 time 219666666.0 	 nearest_idx from skeleton file 571 	 nearest_time 219504809.0
# kth frame = 577 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_577_skfr_571.npy
# k (video frame)  578 	 time 220000000.0 	 nearest_idx from skeleton file 573 	 nearest_time 220164659.0
# kth frame = 578 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_578_skfr_573.npy
# k (video frame)  579 	 time 220333333.0 	 nearest_idx from skeleton file 573 	 nearest_time 220164659.0
# kth frame = 579 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_579_skfr_573.npy
# k (video frame)  580 	 time 220666666.0 	 nearest_idx from skeleton file 574 	 nearest_time 220504915.0
# kth frame = 580 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_580_skfr_574.npy
# k (video frame)  581 	 time 221000000.0 	 nearest_idx from skeleton file 576 	 nearest_time 221164778.0
# kth frame = 581 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_581_skfr_576.npy
# k (video frame)  582 	 time 221333333.0 	 nearest_idx from skeleton file 576 	 nearest_time 221164778.0
# kth frame = 582 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_582_skfr_576.npy
# k (video frame)  583 	 time 221666666.0 	 nearest_idx from skeleton file 577 	 nearest_time 221504714.0
# kth frame = 583 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_583_skfr_577.npy
# k (video frame)  584 	 time 222000000.0 	 nearest_idx from skeleton file 578 	 nearest_time 222164606.0
# kth frame = 584 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_584_skfr_578.npy
# k (video frame)  585 	 time 222333333.0 	 nearest_idx from skeleton file 578 	 nearest_time 222164606.0
# kth frame = 585 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_585_skfr_578.npy
# k (video frame)  586 	 time 222666666.0 	 nearest_idx from skeleton file 579 	 nearest_time 222504774.0
# kth frame = 586 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_586_skfr_579.npy
# k (video frame)  587 	 time 223000000.0 	 nearest_idx from skeleton file 581 	 nearest_time 223164595.0
# kth frame = 587 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_587_skfr_581.npy
# k (video frame)  588 	 time 223333333.0 	 nearest_idx from skeleton file 581 	 nearest_time 223164595.0
# kth frame = 588 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_588_skfr_581.npy
# k (video frame)  589 	 time 223666666.0 	 nearest_idx from skeleton file 582 	 nearest_time 223504693.0
# kth frame = 589 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_589_skfr_582.npy
# k (video frame)  590 	 time 224000000.0 	 nearest_idx from skeleton file 584 	 nearest_time 224164620.0
# kth frame = 590 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_590_skfr_584.npy
# k (video frame)  591 	 time 224333333.0 	 nearest_idx from skeleton file 584 	 nearest_time 224164620.0
# kth frame = 591 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_591_skfr_584.npy
# k (video frame)  592 	 time 224666666.0 	 nearest_idx from skeleton file 585 	 nearest_time 224504744.0
# kth frame = 592 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_592_skfr_585.npy
# k (video frame)  593 	 time 225000000.0 	 nearest_idx from skeleton file 587 	 nearest_time 225164706.0
# kth frame = 593 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_593_skfr_587.npy
# k (video frame)  594 	 time 225333333.0 	 nearest_idx from skeleton file 587 	 nearest_time 225164706.0
# kth frame = 594 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_594_skfr_587.npy
# k (video frame)  595 	 time 226000000.0 	 nearest_idx from skeleton file 589 	 nearest_time 226164792.0
# kth frame = 595 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_595_skfr_589.npy
# k (video frame)  596 	 time 226333333.0 	 nearest_idx from skeleton file 589 	 nearest_time 226164792.0
# kth frame = 596 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_596_skfr_589.npy
# k (video frame)  597 	 time 226666666.0 	 nearest_idx from skeleton file 590 	 nearest_time 226504735.0
# kth frame = 597 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_597_skfr_590.npy
# k (video frame)  598 	 time 227000000.0 	 nearest_idx from skeleton file 592 	 nearest_time 227164620.0
# kth frame = 598 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_598_skfr_592.npy
# k (video frame)  599 	 time 227333333.0 	 nearest_idx from skeleton file 592 	 nearest_time 227164620.0
# kth frame = 599 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_599_skfr_592.npy
# k (video frame)  600 	 time 227666666.0 	 nearest_idx from skeleton file 593 	 nearest_time 227833940.0
# kth frame = 600 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_600_skfr_593.npy
# k (video frame)  601 	 time 228000000.0 	 nearest_idx from skeleton file 594 	 nearest_time 228164654.0
# kth frame = 601 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_601_skfr_594.npy
# k (video frame)  602 	 time 228666666.0 	 nearest_idx from skeleton file 595 	 nearest_time 228504708.0
# kth frame = 602 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_602_skfr_595.npy
# k (video frame)  603 	 time 229000000.0 	 nearest_idx from skeleton file 596 	 nearest_time 229164646.0
# kth frame = 603 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_603_skfr_596.npy
# k (video frame)  604 	 time 229333333.0 	 nearest_idx from skeleton file 596 	 nearest_time 229164646.0
# kth frame = 604 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_604_skfr_596.npy
# k (video frame)  605 	 time 229666666.0 	 nearest_idx from skeleton file 597 	 nearest_time 229504885.0
# kth frame = 605 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_605_skfr_597.npy
# k (video frame)  606 	 time 230000000.0 	 nearest_idx from skeleton file 599 	 nearest_time 230164782.0
# kth frame = 606 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_606_skfr_599.npy
# k (video frame)  607 	 time 230333333.0 	 nearest_idx from skeleton file 599 	 nearest_time 230164782.0
# kth frame = 607 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_607_skfr_599.npy
# k (video frame)  608 	 time 231000000.0 	 nearest_idx from skeleton file 601 	 nearest_time 231164851.0
# kth frame = 608 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_608_skfr_601.npy
# k (video frame)  609 	 time 231333333.0 	 nearest_idx from skeleton file 601 	 nearest_time 231164851.0
# kth frame = 609 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_609_skfr_601.npy
# k (video frame)  610 	 time 231666666.0 	 nearest_idx from skeleton file 602 	 nearest_time 231504999.0
# kth frame = 610 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_610_skfr_602.npy
# k (video frame)  611 	 time 232000000.0 	 nearest_idx from skeleton file 603 	 nearest_time 232164638.0
# kth frame = 611 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_611_skfr_603.npy
# k (video frame)  612 	 time 232333333.0 	 nearest_idx from skeleton file 603 	 nearest_time 232164638.0
# kth frame = 612 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_612_skfr_603.npy
# k (video frame)  613 	 time 233000000.0 	 nearest_idx from skeleton file 606 	 nearest_time 233164616.0
# kth frame = 613 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_613_skfr_606.npy
# k (video frame)  614 	 time 233333333.0 	 nearest_idx from skeleton file 606 	 nearest_time 233164616.0
# kth frame = 614 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_614_skfr_606.npy
# k (video frame)  615 	 time 233666666.0 	 nearest_idx from skeleton file 607 	 nearest_time 233504719.0
# kth frame = 615 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_615_skfr_607.npy
# k (video frame)  616 	 time 234000000.0 	 nearest_idx from skeleton file 608 	 nearest_time 233833938.0
# kth frame = 616 (1080, 1920, 3)
#
# /s/red/b/nobackup/data/eggnog_cpm/test1_paf_hm/20160205_191417_00_Video 20160205_191417_00_Video_vfr_616_skfr_608.npy
# mismatch_count = 0
